# %% [markdown]
# ### 《價量相關性 CPV 因子》

# %%
import pandas as pd
import warnings 
import Factor
warnings.filterwarnings("ignore")

# %%
df = pd.read_feather('/Users/kuanhsu/Desktop/code/Python/FILE/股價5分K.ftr')

factor = Factor.CPV(df)
report = factor.sim(ngroups=10)
report.display('CPV')

# %%
report.stats()
# Out:
# IC Mean                        -0.04
# Rank IC                        -0.07
# ICIR                           -5.23
# Rank ICIR                      -8.38
# Total Return [%]              202.21
# Total Benchmark Return [%]     56.09
# Return [%]                     48.40
# Benchmark Return [%]           17.22
# Volatility [%]                 14.56
# MDD [%]                         3.68
# Win Rate [%]                   60.76
# Information Ratio               2.11
# dtype: float64

# %% [markdown]
# ---
